# %%
import numpy as np
import pandas as pd

# %%
songdata = pd.read_csv("songdata.csv")

print(songdata.shape)
songdata.head()
# Out:
# (57650, 4)
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
songdata.columns
# Out:
# Index(['artist', 'song', 'link', 'text'], dtype='object')

# %%
songdata_1 = songdata.groupby(["artist"]).size().reset_index(name="Counts")
songdata_1
# Out:
#                           artist  Counts
# 0                        'n Sync      93
# 1                           ABBA     113
# 2                    Ace Of Base      74
# 3                   Adam Sandler      70
# 4                          Adele      54
# 5                      Aerosmith     171
# 6                     Air Supply     174
# 7                  Aiza Seguerra      25
# 8                        Alabama     187
# 9           Alan Parsons Project     102
# 10                    Aled Jones      23
# 11                  Alice Cooper     174
# 12               Alice In Chains      95
# 13                 Alison Krauss     145
# 14          Allman Brothers Band     116
# 15                    Alphaville     105
# 16                       America     184
# 17                     Amy Grant     147
# 18                Andrea Bocelli      25
# 19                 Andy Williams     138
# 20                         Annie      32
# 21                 Ariana Grande      51
# ...
