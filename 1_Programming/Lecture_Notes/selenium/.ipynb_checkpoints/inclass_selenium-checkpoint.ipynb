# %% [markdown]
# # Selenium Basic

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("http://www.naver.com")

# %%
driver.set_window_size(800, 700)

# %%
# execute_script = javascript code를 실행하는 것
# 자바스크립트 명령어로 스크롤 이동
driver.execute_script("window.scrollTo(0, 0);")

# %%
# 메인 윈도우의 위치를 저장
# driver.current_window_handle 현재 naver페이지
# main_window로 지정
# 탭 이동을 할 때 사용
main_window = driver.current_window_handle
main_window
# Out:
# 'CDwindow-(82CD2B631D905B515531667077955A3)'

# %%
#새로운 탭 오픈
driver.execute_script("window.open('https://www.google.com');")

# %%
# driver는 여전히 naver페이지를 포커싱 하고 있음
driver.get('http://daum.net/')

# %%
windows = driver.window_handles
windows
# Out:
# ['CDwindow-(82CD2B631D905B515531667077955A3)',
#  'CDwindow-(A85C5A86CB28EA4B265D5ECD879C7A29)']

# %%
# change focus
driver.switch_to_window(windows[1])

# %%
driver.get('http://facebook.com/')

# %%
driver.switch_to_window(main_window)

# %%
# page reload
driver.execute_script("location.reload();")

# %% [markdown]
# # Alert
#
# alert창이 뜰 경우,
# 이것을 통해서 alert창을 닫고 계속 이동

# %%
# open alert
driver.execute_script("alert('selenium test');")
# driver.execute_script("confirm('confirm?');")

# %%
# focus alert
# alert 객체를 받아 'alert'에 지정
alert = driver.switch_to_alert()

# %%
# get alert text
alert.text
# Out:
# 'selenium test'

# %%
# close alert
alert.accept() # 확인   # 확인버튼 alert이 눌려져서 닫힘
# alert.dismiss() # 취소

# %%
driver.execute_script("confirm('confirm?');")

# %%
alert = driver.switch_to_alert()

# %%
alert.text
# Out:
# 'confirm?'

# %%
alert.dismiss() # 취소

# %% [markdown]
# data 넣어보기

# %%
# 다음 검색창(id="q")에 '패스트캠퍼스 입력'
driver.find_element_by_css_selector( "#q" ).send_keys( "패스트캠퍼스" )

# %%
# 검색 버튼 (class="ico_pctop.btn_search")
driver.find_element_by_css_selector(".ico_pctop.btn_search").click()
# driver.find_element_by_css_selector("#daumBtnSearch").click()

# %%
# id나 class를 이용해서 입력하면 됨 (id가 있다면, 되도록이면 id = page 내에서 유니크한 값이기 때문)
driver.find_element_by_css_selector(".ico_ksearch.btn_ksearch").click()

# %%
driver.close()

# %%
for window in driver.window_handles:
    driver.switch_to_window(window)
    driver.close()

# %%
#PM_ID_ct > div.header > div.section_navbar > div.area_hotkeyword.PM_CL_realtimeKeyword_base > div.ah_roll.PM_CL_realtimeKeyword_rolling_base > div > ul > li:nth-child(11) > a > span.ah_k

# %%
# 네이버 검색창(id="q")에 '패스트캠퍼스 입력'
driver.find_element_by_css_selector( "#query" ).send_keys( "패스트캠퍼스" )

# %%
driver.find_element_by_css_selector(".ico_search_submit").click()

# %% [markdown]
# # Selenium File
#
# iframe으로 넣었을 때 뜨는 페이지를 이미지로 확인
# iframe 안으로 포커스 이동 후 데이터 추출
#
# (ex)
# API 내 iframed으로 포커스를 옮기고,
# 파일 업로드 하고 결과 도출하기

# %%
import time
from selenium import webdriver

# %%
driver =  webdriver.Chrome()

# %%
driver.get('https://cloud.google.com/vision/')

# %% [markdown]
# Try the API 내 iframe에 접근

# %%
iframe = driver.find_element_by_css_selector("#vision_demo_section iframe")

# %%
driver.switch_to_frame(iframe)

# %%
# default로 빠져나올 때
# switch back default content
# driver.switch_to_default_content()

# %%
# 현재 경로 확인
# !pwd
# Out:
# /Users/Seoluca/Data_Analytics/FastCampus/Data_Science_School/1_Programming/Lecture_Notes/selenium

# %%
path = !pwd

# %%
path
# Out:
# ['/Users/Seoluca/Data_Analytics/FastCampus/Data_Science_School/1_Programming/Lecture_Notes/selenium']

# %%
# 경로 내 스크린샷 이미지를 추가하여 경로 재설정
# input에 이미지를 추가 (이미지가 포함된 경로 추가)
file_path = path[0] + "/screenshot_element.png"
driver.find_element_by_css_selector("#input").send_keys(file_path)

# %%
# WEB 클릭
driver.find_element_by_css_selector("#webDetection").click()

# %%
driver.find_elements_by_css_selector('.vs-web .name')[0].text
# Out:
# 'Tim Cook'

# %%
driver =  webdriver.Chrome()
driver.get('https://cloud.google.com/vision/')

iframe = driver.find_element_by_css_selector("#vision_demo_section iframe")
driver.switch_to_frame(iframe)
file_path = path[0] + "/screenshot_element.png"
driver.find_element_by_css_selector("#input").send_keys(file_path)
time.sleep(10) # 이미지를 업로드하고 데이터를 분석하는 시간
driver.find_element_by_css_selector("#webDetection").click()
result = driver.find_elements_by_css_selector('.vs-web .name')[2].text
print(result)
driver.close()
# Out:
# iPhone 8

# %% [markdown]
# element 있는지 체크 (try, exempt)

# %%
def check_element(driver, selector):
    try:
        driver.find_element_by_css_selector(selector)
        return True
    except:
        return False

# %%
driver =  webdriver.Chrome()
driver.get('https://cloud.google.com/vision/')

iframe = driver.find_element_by_css_selector("#vision_demo_section iframe")
driver.switch_to_frame(iframe)
file_path = path[0] + "/screenshot_element.png"
driver.find_element_by_css_selector("#input").send_keys(file_path)

selector = '.vs-web .name'
sec, limit_sec = 0, 5 # 몇 초까지 기다르겠느냐
while True:
    sec += 1
    print("{}sec".format(sec))
    time.sleep(1)
    
    # element 확인
    if check_element(driver, selector):
        driver.find_element_by_css_selector("#webDetection").click()
        result = driver.find_elements_by_css_selector(selector)[0].text
        print(result)
        driver.close()
        break;
        
    # limit_sec가 넘어가면 에러 처리
    if sec + 1 > limit_sec:
        print("error")
        driver.close()
        break;
# Out:
# 1sec
# 2sec
# 3sec
# 4sec
# 5sec
# error

# %%
driver =  webdriver.Chrome()
driver.get('https://cloud.google.com/vision/')

iframe = driver.find_element_by_css_selector("#vision_demo_section iframe")
driver.switch_to_frame(iframe)
file_path = path[0] + "/screenshot_element.png"
driver.find_element_by_css_selector("#input").send_keys(file_path)

selector = '.vs-web .name'
sec, limit_sec = 0, 10 # 몇 초까지 기다르겠느냐
while True:
    sec += 1
    print("{}sec".format(sec))
    time.sleep(1)
    
    # element 확인
    if check_element(driver, selector):
        driver.find_element_by_css_selector("#webDetection").click()
        result = driver.find_elements_by_css_selector(selector)[0].text
        print(result)
        driver.close()
        break;
        
    # limit_sec가 넘어가면 에러 처리
    if sec + 1 > limit_sec:
        print("error")
        driver.close()
        break;
# Out:
# 1sec
# 2sec
# 3sec
# 4sec
# 5sec
# 6sec
# Tim Cook

# %% [markdown]
# # Selenium Image

# %% [markdown]
# install pillow

# %%
import time
from selenium import webdriver
from PIL import Image as pil

# %%
# 브라우져를 열고 youtube 페이지로 이동하여 브라우져 화면을 이미지로 저장합니다. 
driver =  webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=tXOJIBPwSyo&t=365s") #6분 5초 후 재생
time.sleep(1)    # 로딩 대기 시간
driver.save_screenshot('screenshot.png')
# Out:
# True

# %%
# show image
# 저장된 이미지파일의 사이즈와 이미지를 pillow를 이용하여 확인 합니다.
pil_im = pil.open('screenshot.png')
print(pil_im.size)
pil_im
# Out:
# (2400, 1164)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2400x1164 at 0x11746C278>

# %%
# change image size
# pillow를 이용하여 256*256 사이즈로 이미지의 크기를 변환합니다.
pil_im.thumbnail((256, 256))
pil_im.save("screenshot_thumnail.png")
pil.open('screenshot_thumnail.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x124 at 0x116C7A438>

# %%
# 특정 영역
# 특정 selector의 element의 위치와 사이즈 데이터를 확인합니다.
element = driver.find_element_by_css_selector('#movie_player')
location = element.location
size = element.size
location, size
# Out:
# ({'x': 60, 'y': 80}, {'height': 360, 'width': 640})

# %%
# 저장했던 원본이미지를 열어 top, bottom, right, left의 위치를 계산합니다.
# 딱 영상 부분 위치를 찍어준 것
pil_im = pil.open('screenshot.png')
left = location['x'] * 2
top = location['y'] * 2
right = left + size['width'] * 2
bottom = top + size['height'] * 2
area = (left, top, right, bottom)
area
# Out:
# (120, 160, 1400, 880)

# %%
# 스샷이미지에서 딱 지정한 영상 부분을 crop
pil_im = pil_im.crop(area)

# %%
# 자른 이미지를 저장하고 저장된 이미지를 보여줍니다.
pil_im.save("screenshot_element.png")
pil.open('screenshot_element.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720 at 0x11746CEB8>

# %%
# 브라우져 닫기
driver.close()

# %% [markdown]
# # Scraping
