# %% [markdown]
# ### Pandas Visualization
# - https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()   # 누적 시킨다
ts.plot()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.tail()
# Out:
#                     A          B          C         D
# 2002-09-22  47.109483  51.325145  10.014417  7.966064
# 2002-09-23  44.740095  51.057153  10.390907  7.638345
# 2002-09-24  45.656705  49.552498  11.821502  6.905834
# 2002-09-25  46.954478  49.659433  12.313394  7.246078
# 2002-09-26  47.334435  49.296466  11.214701  8.582324

# %%
df.plot()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# - bar
# - pie
# - scatter

# %% [markdown]
# ##### Seaborn data set
# - https://github.com/mwaskom/seaborn-data

# %%
iris = sns.load_dataset("iris")
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris[:10].plot()
plt.show()

# %%
iris[:10].plot(kind="bar")
plt.show()

# %%
iris.species.value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
iris_pie = iris.species.value_counts()
iris_pie.plot.pie(autopct='%d%%') # decimal %
plt.axis('equal')   # 안 쓰게 되면 index가 붙어버린다
plt.show()

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width')
plt.show()

# %%
setosa = iris[iris["species"] == "setosa"]
versicolor = iris[iris["species"] == "versicolor"]
virginica = iris[iris["species"] == "virginica"]

# %%
ax = setosa.plot.scatter(x='sepal_length', y='sepal_width', c="red")
versicolor.plot.scatter(x='sepal_length', y='sepal_width', c="blue", ax=ax)
virginica.plot.scatter(x='sepal_length', y='sepal_width', c="black", ax=ax)
plt.show()
