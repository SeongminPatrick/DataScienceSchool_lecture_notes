# %% [markdown]
# ### matplotlib 2
# - line plot
# - bar chart
# - pie chart
# - sactter plot
# - histogram
#
#
# - boxplot
# - violinplot

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Bar plot : 크기를 비교할 때

# %%
y = np.random.randint(10, size=5)
x = range(5)
plt.bar(x, y)
plt.show()

# %%
y = np.random.randint(5, 10, size=5)
x = range(5) 
error = np.random.randint(1, 5, size=5)
print(y, error)
plt.bar(x, y, yerr=error, align='center', alpha=0.2)
plt.show()
# Out:
# [5 6 8 5 8] [3 2 4 4 1]

# %%
y = np.random.randint(5, 10, size=5)
x = range(5) 
error = np.random.randint(1, 5, size=5)
print(y, error)
plt.barh(x, y, xerr=error, align='center', alpha=0.6)
plt.show()
# Out:
# [6 8 6 7 7] [4 3 2 1 2]

# %%
y1 = np.random.randint(5, 10, size=5)
y2 = np.random.randint(1, 5, size=5)    # 더 큰 데이터를 먼저, 작은 데이터는 나중에 그려줘야 bar plot이 그려짐
print(y1, y2)
plt.subplots()
x = range(5)
plt.bar(x, y1)
plt.bar(x, y2)
plt.tight_layout()
plt.show()
# Out:
# [6 5 8 6 7] [2 4 3 4 4]

# %%
y1 = np.random.randint(1, 5, size=5)
y2 = np.random.randint(1, 5, size=5)
bar_width, opacity = 0.4, 0.6     # 바 넓이, opacity
print(y1, y2, bar_width, opacity)
x = np.arange(5)

plt.bar(x, y1, bar_width, alpha=opacity, color='b', label='randint_1', align="edge")
plt.bar(x + bar_width, y2, bar_width, alpha=opacity, color='r', label='randint_2', align="edge")

plt.xlabel('X Label') # X 라벨
plt.ylabel('Value')   # Y 라벨
plt.xticks(x + bar_width, ('A', 'B', 'C', 'D', 'E')) # xtick 추가
plt.title('Random Integer') # 제목추가
plt.legend() # 범례추가
plt.show()
# Out:
# [1 2 3 3 2] [2 1 1 4 2] 0.4 0.6

# %% [markdown]
# ##### pie plot  :  비율을 나타날 때

# %%
data = np.random.randint(1,6, size=5)
labels = ['A','B','C','D','E']
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red']
print(data)
plt.pie(data, labels=labels, colors=colors, autopct='%1.3f%%')    # autopct : 몇 번 째 자리까지 나오는 지 d:자연수, g:반올림, f:소수점
plt.show()
# Out:
# [2 3 1 3 3]

# %% [markdown]
# ##### sactter plot : 분산의 정도를 볼 때

# %%
# uniform (균등분포)
x1 = np.random.rand(500)
y1 = np.random.rand(500)
plt.subplot(311)
plt.scatter(x1, y1)

# gaussian (정규분포)
x2 = np.random.randn(500)
y2 = np.random.randn(500)
plt.subplot(312)
plt.scatter(x2, y2)

# randint (uniform)
x3 = np.random.randint(1,100,size=500)
y3 = np.random.randint(1,100,size=500)
plt.subplot(313)
plt.scatter(x3, y3)

plt.show()

# %%
data1 = np.random.randint(1,10, size=20)
data2 = np.random.randint(1,10, size=20)
colors = np.random.rand(20)
area = np.pi * np.arange(10,50,2) ** 2
plt.scatter(data1, data2, s=area, c=colors, alpha=0.5)
plt.show()


# N = 50
# x = np.random.rand(N)
# y = np.random.rand(N)

# area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# plt.show()

# %% [markdown]
# ##### histogram : 분포도를 볼 때

# %%
# 50개의 구간을로 잘라 해당되는 데이터의 수를 카운트한 후에 y축의 값을 normalized 한다
x1 = np.random.rand(1000)
plt.subplot(211)
plt.hist(x1, bins=50, normed=True)

x2 = np.random.randn(1000)
plt.subplot(212)
plt.hist(x2, bins=50, normed=True) # bins : 몇 등분으로 나눌 지

plt.show()

# %%
x = np.random.randint(0,100, size=100)
print(x, np.bincount(x))
plt.subplot(311)
plt.hist(x)
plt.subplot(312)
plt.hist(x, bins=100)
plt.subplot(313)
plt.hist(x, normed=True)

plt.show()
# Out:
# [87 81 64 69 59 27 97 78 46  9  8 86 48 99 96 92 75 22 56 40 12 83 92 39 72
#  60 67 55 46 90 63 46 92 50  4 78 48 75 66 42 26 19  0 31 38 53 96 30 53 64
#  49  0 90 74 54 99 47 46 34 22 56 23 81 48 99 89 36 98 49 50 57 16 58 66 48
#  31 36 60 48 30  2 68 23 58 46 76 23 42 50 21 35 88 83 18 87 55 69 97  3 84] [2 0 1 1 1 0 0 0 1 1 0 0 1 0 0 0 1 0 1 1 0 1 2 3 0 0 1 1 0 0 2 2 0 0 1 1 2
#  0 1 1 1 0 2 0 0 0 5 1 5 2 3 0 0 2 1 2 2 1 2 1 2 0 0 1 2 0 2 1 1 2 0 0 1 0
#  1 2 1 0 2 0 0 2 0 2 1 0 1 2 1 1 2 0 3 0 0 0 2 2 1 3]
