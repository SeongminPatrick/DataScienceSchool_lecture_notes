# %% [markdown]
# ### Reference
# - https://matplotlib.org/gallery.html

# %% [markdown]
# ### matplotlib 1
# - setting
# - basic line plot
# - xtick 추가
# - style
#     - 마커
#     - 라인
#     - 색상
# - limit 설정
# - ticks 설정
# - grid 추가
# - multy line 그리기
# - legend (범례)
# - title
# - 한글폰트 적용
# - Figure
#     - 그래프 크기조절
#     - 여러개 그래프 출력

# %% [markdown]
# ##### setting

# %%
# %matplotlib notebook

# %%
# or
# %matplotlib inline

# %%
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Basic Line Plot

# %%
data = np.random.randint(10, size=10)
print(data)
plt.plot(data)
plt.show()
# Out:
# [8 2 9 1 5 7 7 6 9 0]

# %% [markdown]
# ##### xtick 추가

# %%
data = np.random.randint(10, size=10)
print(data)
xtick = range(0,100,10)
plt.plot(xtick, data)
plt.show()
# Out:
# [1 6 7 1 8 1 1 3 4 2]

# %% [markdown]
# ##### 스타일
# 색상
# - https://matplotlib.org/examples/color/named_colors.html
# - blue : b
# - green : g
# - red : r
# - cyan : c
# - magenta : m
# - yellow : y
# - black : k
# - white : w
#
# 마커
# - . : point marker
# - , : pixel marker
# - o : circle marker
# - v : triangle_down marker
# - ^ : triangle_up marker
# - < : triangle_left marker
# - `>` : triangle_right marker
# - 1 : tri_down marker
# - 2 : tri_up marker
# - 3 : tri_left marker
# - 4 : tri_right marker
# - s : square marker
# - p : pentagon marker
# - `*` : star marker
# - h : hexagon1 marker
# - H : hexagon2 marker
# - `+` : plus marker
# - x : x marker
# - D : diamond marker
# - d : thin_diamond marker
#
# 라인 스타일
# - `-` : solid line style
# - `--` : dashed line style
# - `-.` : dash-dot line style
# - `:` : dotted line style
#
# 커스텀 스타일
# - c : 선 색상
# - lw : 선 굵기
# - ls : 선 스타일
# - marker : 마커 종류
# - ms : 마커 크기
# - mec : 마커 선 색깔
# - mew : 마커 선 굵기
# - mfc : 마커 내부 색깔

# %%
data = np.random.randint(10, size=10)
plt.plot(data, 'ch:')  # --> m(magenta) + s(square) + :(solid line style)
plt.show()

# %%
data = np.random.randint(10, size=10)
plt.plot(data, c="r", lw=4, ls="--", marker="D", ms="10", mec="g", mew="3", mfc="w")
plt.show()

# %% [markdown]
# ##### limit 설정

# %%
# xlim, ylim 설정
data = np.random.randint(10, size=10)
plt.xlim(-5, 20)   # limit : start value, end value
plt.ylim(-10, 30)
plt.plot(data)
plt.show()

# %% [markdown]
# ##### tick 설정

# %%
data = np.random.randint(5, size=5)
plt.plot(data)
plt.show()

# %%
plt.plot(data)
plt.xticks(range(5))
plt.yticks([2,4])
plt.show()

# %% [markdown]
# ##### 그리드 추가

# %%
data = np.random.randint(10, size=10)
plt.grid(True)   # 그리드 추가
plt.plot(data)
plt.show()

# %% [markdown]
# ##### 멀티 라인 그리기

# %%
data1 = np.random.randint(5, size=5)
data2 = np.random.randint(5, size=5)
data3 = np.random.randint(5, size=5)
xticks = range(0,5)
print(data1, data2, data3)

plt.plot(xticks, data1, 'ro-', xticks, data2, 'g^:', xticks, data3, 'b*--')  # (틱, 자료, 스타일)
plt.show()
# Out:
# [2 0 2 0 3] [3 4 4 4 0] [4 2 0 4 3]

# %%
xticks = range(0,5)
print(data1, data2, data3)

plt.plot(xticks, data1)
plt.plot(xticks, data2)
plt.plot(xticks, data3)
plt.show()

# %% [markdown]
# ##### legend (범례)
# 범례 위치
# - best : 0
# - upper right : 1
# - upper left : 2
# - lower left : 3
# - lower right : 4
# - right : 5
# - center left : 6
# - center right : 7
# - lower center : 8
# - upper center : 9
# - center : 10

# %%
data1 = np.random.randint(7, size=5)
data2 = np.random.randint(7, size=5)
plt.plot(data1, label="data1")
plt.plot(data2, label="data2")
plt.legend(loc=0)
plt.show()

# %%
data1 = np.random.randint(3, size=5)
data2 = np.random.randint(3, size=5)
plt.plot(data1, label="data1")
plt.plot(data2, label="data2")
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ##### title 추가

# %%
data = np.random.randint(5, size=5)
plt.plot(data)
plt.xlabel("xtick")
plt.ylabel("ytick")
plt.title("Title")
plt.show()

# %%
data = np.random.randint(5, size=5)
plt.plot(data)
plt.xlabel("x축")
plt.ylabel("y축")
plt.title("타이틀")
plt.show()

# %% [markdown]
# ##### 한글 폰트 적용

# %%
# 방법 1
# 설정파일에서 폰트 수정

# %%
# 현재 폰트 확인
mpl.rcParams["font.family"]
# Out:
# ['sans-serif']

# %%
# 설정파일 위치 확인
mpl.matplotlib_fname()
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
# 방법 1
# 설정파일에서 font 설정 추가
# font.family     : AppleMyungjo

# %%
# 방법2
# 폰트 경로를 지정
import matplotlib.font_manager as fm
font_location = "/Library/Fonts/AppleGothic.ttf"
font_name = fm.FontProperties(fname=font_location).get_name()
mpl.rc('font', family=font_name)

# %%
mpl.rcParams["font.family"]
# Out:
# ['AppleGothic']

# %%
data = np.random.randint(5, size=5)
plt.plot(data)
plt.grid(True)
plt.xlabel("x축")
plt.ylabel("y축")
plt.title("타이틀")
plt.show()

# %% [markdown]
# ### Figure
# - 그래프의 크기를 조절
# - 여러개의 그래프 출력

# %% [markdown]
# ##### 그래프 크기 조절

# %%
data = np.random.randint(5, size=5)
f1 = plt.figure(figsize=(2, 3)) #(가로, 세로)
plt.plot(data)
plt.show()

# %%
data = np.random.randint(5, size=5)
f1 = plt.figure(figsize=(5, 5)) #(가로, 세로)
plt.grid(True)
plt.plot(data)
plt.show()

# %% [markdown]
# ##### 여러개 그래프 출력

# %%
data1 = np.random.randint(5, size=5)
data2 = np.random.randint(5, size=5)
print(data1, data2)

plt.subplot(2, 1, 1) # 2*1에서 1번 위치
plt.grid(True)
plt.plot(data1)

plt.subplot(2, 1, 2) # 2*1에서 2번 위치
plt.plot(data2)

plt.show()
# Out:
# [4 0 2 0 3] [3 0 3 4 1]

# %%
data1 = np.random.randint(5, size=5)
data2 = np.random.randint(5, size=5)
data3 = np.random.randint(5, size=5)
data4 = np.random.randint(5, size=5)

print(data1, data2, data3, data4)

plt.subplot(221) # 2*2에서 1번 위치
plt.plot(data1)

plt.subplot(222) # 2*2에서 2번 위치
plt.plot(data2)

plt.subplot(223) # 2*2에서 3번 위치
plt.plot(data3)

plt.subplot(224) # 2*2에서 4번 위치
plt.plot(data4)

plt.show()
# Out:
# [2 1 4 3 4] [2 4 0 2 2] [3 0 0 1 2] [0 3 4 3 4]
